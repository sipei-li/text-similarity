# %%
from visualize import bert_visualize, word2vec_visualize
import numpy as np
# %load_ext autoreload
# %autoreload 2
# %autosave 60
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Autosaving every 60 seconds

# %% [markdown]
# ## Visualization and similarity using BERT embedding

# %%
doc1 = 'omaba speaks to the media in illinois'
doc2 = 'omaba, working for a press, was born in chicago'
doc3 = 'the president greets the press in chicago'

# %%
bert_visualize(doc2,doc1)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="81cff5c0e69b422f8eb1e57e0d45cd2d-0" class="displacy" width="950" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">omaba,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">working</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
# ...

# %%
bert_visualize(doc3,doc1)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c99e329c738c437ba6864371b2fb1a20-0" class="displacy" width="750" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">president</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
# ...

# %%
print('word mover distance')
np.load('../data/obama/processed/wms_obama.npy')
# Out:
# word mover distance
# array([[0.        , 0.87012551, 0.69753152],
#        [0.87012551, 0.        , 0.54799458],
#        [0.69753152, 0.54799458, 0.        ]])

# %%
print('word mover similarity')
np.load('../data/obama/processed/wmd_obama.npy')
# Out:
# word mover similarity
# array([[1.        , 0.12987449, 0.30246848],
#        [0.12987449, 1.        , 0.45200542],
#        [0.30246848, 0.45200542, 1.        ]])

# %%
print('graph similarity using node match threshold 0')
np.load('../data/obama/processed/graph_similarity_obama_00.npy')
# Out:
# graph similarity using node match threshold 0
# array([[1.        , 0.66340186, 0.75610684],
#        [0.66340186, 1.        , 0.64741862],
#        [0.75610684, 0.64741862, 1.        ]])

# %%
print('graph similarity using node match threshold 0.9')
np.load('../data/obama/processed/graph_similarity_obama_09.npy')
# Out:
# graph similarity using node match threshold 0.9
# array([[1.        , 0.66340186, 0.75610684],
#        [0.66340186, 1.        , 0.64741862],
#        [0.75610684, 0.64741862, 1.        ]])

# %% [markdown]
# ## Visualization and similarity using word2vec embedding

# %%
word2vec_visualize(doc2,doc1)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="64622a3da45c4046afdab4df0ca3f098-0" class="displacy" width="950" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">omaba,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">working</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
# ...

# %%
word2vec_visualize(doc3,doc1)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9b696af15a7f487a8b2f2053a9bb8e52-0" class="displacy" width="750" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">president</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
# ...

# %%
print('word mover distance')
np.load('../data/obama/processed/wms_obama.npy')
# Out:
# word mover distance
# array([[0.        , 0.45466165, 0.50741856],
#        [0.45466165, 0.        , 0.82164901],
#        [0.50741856, 0.82164901, 0.        ]])

# %%
print('word mover similarity')
np.load('../data/obama/processed/wmd_obama.npy')
# Out:
# word mover similarity
# array([[1.        , 0.54533835, 0.49258144],
#        [0.54533835, 1.        , 0.17835099],
#        [0.49258144, 0.17835099, 1.        ]])

# %%
print('graph similarity using node match threshold 0')
np.load('../data/obama/processed/graph_similarity_obama_00.npy')
# Out:
# graph similarity using node match threshold 0
# array([[1.        , 0.72674813, 1.12428894],
#        [0.72674813, 1.        , 0.75381571],
#        [1.12428894, 0.75381571, 1.        ]])

# %%
print('graph similarity using node match threshold 0.9')
np.load('../data/obama/processed/graph_similarity_obama_09.npy')
# Out:
# graph similarity using node match threshold 0.9
# array([[1.        , 0.72674813, 1.12428894],
#        [0.72674813, 1.        , 0.75381571],
#        [1.12428894, 0.75381571, 1.        ]])
